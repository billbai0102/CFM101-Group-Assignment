# %%
from IPython.display import display, Math, Latex

import pandas as pd
import numpy as np
import numpy_financial as npf
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ## Group Assignment
# ### Team Number: 12
# ### Team Member Names: Bill Bai, Soumik Debnath, Justin Yu
# ### Team Strategy Chosen: RISKY

# %%
# Read file and save as DF
tickers_path = "./Tickers.csv"
tickers_df = pd.read_csv(tickers_path, header=None).rename(columns={0:'Ticker'})

# %%
# Create an info cell for each ticker, saving time when filtering the tickers by volume and country.
info_column = {}
ticker_obj_lst = []

# Add info to dict
for idx, row in tickers_df.iterrows():
    ticker = row[0] # Get ticker name
    ticker = yf.Ticker(ticker)
    ticker_obj_lst.append(ticker)
    info_column[idx] = ticker.info

# Create column for the info]
tickers_df['Info'] = pd.Series(info_column)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/7v/dw2dmzws3px3k10mxmkfszmc0000gn/T/ipykernel_85388/3774028815.py in <module>
#       8     ticker = yf.Ticker(ticker)
#       9     ticker_obj_lst.append(ticker)
# ---> 10     info_column[idx] = ticker.info
#      11
#      12 # Create column for the info]
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/yfinance/ticker.py in info(self)
#     141     @property
#     142     def info(self):
# --> 143         return self.get_info()
#     144
#     145     @property
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/yfinance/base.py in get_info(self, proxy, as_dict, *args, **kwargs)
#     497
#     498     def get_info(self, proxy=None, as_dict=False, *args, **kwargs):
# --> 499         self._get_fundamentals(proxy=proxy)
#     500         data = self._info
#     501         if as_dict:
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/yfinance/base.py in _get_fundamentals(self, kind, proxy)
#     307         # holders
#     308         try:
# --> 309             resp = utils.get_html(ticker_url + '/holders', proxy, self.session)
#     310             holders = _pd.read_html(resp)
#     311         except Exception as e:
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/yfinance/utils.py in get_html(url, proxy, session)
#      47 def get_html(url, proxy=None, session=None):
#      48     session = session or _requests
# ---> 49     html = session.get(url=url, proxies=proxy, headers=user_agent_headers).text
#      50     return html
#      51
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     695
#     696         if not stream:
# --> 697             r.content
#     698
#     699         return r
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/requests/models.py in content(self)
#     834                 self._content = None
#     835             else:
# --> 836                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     837
#     838         self._content_consumed = True
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/requests/models.py in generate()
#     756             if hasattr(self.raw, 'stream'):
#     757                 try:
# --> 758                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     759                         yield chunk
#     760                 except ProtocolError as e:
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     765                 if self.chunk_left == 0:
#     766                     break
# --> 767                 chunk = self._handle_chunk(amt)
#     768                 decoded = self._decode(
#     769                     chunk, decode_content=decode_content, flush_decoder=False
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/urllib3/response.py in _handle_chunk(self, amt)
#     718             returned_chunk = value
#     719         else:  # amt > self.chunk_left
# --> 720             returned_chunk = self._fp._safe_read(self.chunk_left)
#     721             self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     722             self.chunk_left = None
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/http/client.py in _safe_read(self, amt)
#     606         IncompleteRead exception can be used to detect the problem.
#     607         """
# --> 608         data = self.fp.read(amt)
#     609         if len(data) < amt:
#     610             raise IncompleteRead(data, amt-len(data))
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
tickers_df
# Out:
#     Ticker                                               Info
# 0     AAPL  {'zip': '95014', 'sector': 'Technology', 'full...
# 1     ABBV  {'zip': '60064-6400', 'sector': 'Healthcare', ...
# 2      ABT  {'zip': '60064-6400', 'sector': 'Healthcare', ...
# 3      ACN  {'zip': '2', 'sector': 'Technology', 'fullTime...
# 4      AGN       {'regularMarketPrice': None, 'logo_url': ''}
# ..     ...                                                ...
# 57     TXN  {'zip': '75243', 'sector': 'Technology', 'full...
# 58     UNH  {'zip': '55343', 'sector': 'Healthcare', 'full...
# 59     UNP  {'zip': '68179', 'sector': 'Industrials', 'ful...
# 60     UPS  {'zip': '30328', 'sector': 'Industrials', 'ful...
# 61  USBcln       {'regularMarketPrice': None, 'logo_url': ''}
#
# [62 rows x 2 columns]

# %%
def filter_us_market(df):
    """
    Consumes a dataframe of tickers and returns a list of booleans representing whether the tickers are US-listed or not.
    :param df: DataFrame containing tickers
    :return: List of booleans representing whether the tickers are US-listed.
    """
    # Initialize mask list of booleans.
    mask = []
    for idx, row in df.iterrows():
        # Check whether stock is US-listed or not, and append the boolean to mask
        info = row['Info']
        if "market" in row['Info']:
            mask.append(info['market'] == 'us_market')
        else:
            mask.append(False)
    # Return mask
    return mask

def filter_volume(df):
    """
    Consumes a dataframe of tickers and returns a list of bo
    :param df:
    :return:
    """
    # Start and end date to check volume
    start_date = "2021-07-02"
    end_date = "2021-10-23"
    mask = []
    for idx, row in df.iterrows():
        ticker = yf.Ticker(row[0])
        ticker_hist = ticker.history(start=start_date, end=end_date)
        mask.append(ticker_hist['Volume'].mean() >= 10000)
    return mask

# %%
tickers_df = tickers_df.loc[filter_us_market(tickers_df)]
tickers_df = tickers_df.loc[filter_volume(tickers_df)]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/7v/dw2dmzws3px3k10mxmkfszmc0000gn/T/ipykernel_81750/676512844.py in <module>
#       1 tickers_df = tickers_df.loc[filter_us_market(tickers_df)]
# ----> 2 tickers_df = tickers_df.loc[filter_volume(tickers_df)]
#       3 tickers_df.reset_index()
#
# /var/folders/7v/dw2dmzws3px3k10mxmkfszmc0000gn/T/ipykernel_81750/2481559256.py in filter_volume(df)
#      29     for idx, row in df.iterrows():
#      30         ticker = yf.Ticker(row[0])
# ---> 31         ticker_hist = ticker.history(start=start_date, end=end_date)
#      32         mask.append(ticker_hist['Volume'].mean() >= 10000)
#      33     return mask
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/yfinance/base.py in history(self, period, interval, start, end, prepost, actions, auto_adjust, back_adjust, proxy, rounding, tz, **kwargs)
#     150         # Getting data from json
#     151         url = "{}/v8/finance/chart/{}".format(self._base_url, self.ticker)
# --> 152         data = self.session.get(
#     153             url=url,
#     154             params=params,
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/http/client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/CFM101/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
tickers_df.reset_index(drop=True)
# Out:
#    Ticker                                               Info
# 0    AAPL  {'zip': '95014', 'sector': 'Technology', 'full...
# 1    ABBV  {'zip': '60064-6400', 'sector': 'Healthcare', ...
# 2     ABT  {'zip': '60064-6400', 'sector': 'Healthcare', ...
# 3     ACN  {'zip': '2', 'sector': 'Technology', 'fullTime...
# 4     AIG  {'zip': '10020', 'sector': 'Financial Services...
# 5    AMZN  {'zip': '98109-5210', 'sector': 'Consumer Cycl...
# 6     AXP  {'zip': '10285', 'sector': 'Financial Services...
# 7      BA  {'zip': '60606-1596', 'sector': 'Industrials',...
# 8     BAC  {'zip': '28255', 'sector': 'Financial Services...
# 9    BIIB  {'zip': '02142', 'sector': 'Healthcare', 'full...
# 10     BK  {'zip': '10286', 'sector': 'Financial Services...
# 11    BLK  {'zip': '10055', 'sector': 'Financial Services...
# 12    BMY  {'zip': '10016', 'sector': 'Healthcare', 'full...
# 13      C  {'zip': '10013', 'sector': 'Financial Services...
# 14    CAT  {'zip': '60015', 'sector': 'Industrials', 'ful...
# 15     CL  {'zip': '10022-7499', 'sector': 'Consumer Defe...
# 16  CMCSA  {'zip': '19103-2838', 'sector': 'Communication...
# 17    COF  {'zip': '22102', 'sector': 'Financial Services...
# 18    COP  {'zip': '77079-2703', 'sector': 'Energy', 'ful...
# 19   COST  {'zip': '98027', 'sector': 'Consumer Defensive...
# 20   CSCO  {'zip': '95134', 'sector': 'Technology', 'full...
# 21    CVS  {'zip': '02895', 'sector': 'Healthcare', 'full...
# 22     GM  {'zip': '48265-3000', 'sector': 'Consumer Cycl...
# 23   GOOG  {'zip': '94043', 'sector': 'Communication Serv...
# 24    JPM  {'zip': '10179', 'sector': 'Financial Services...
# 25    KMI  {'zip': '77002', 'sector': 'Energy', 'fullTime...
# 26     KO  {'zip': '30313', 'sector': 'Consumer Defensive...
# 27    LLY  {'zip': '46285', 'sector': 'Healthcare', 'full...
# 28    LMT  {'zip': '20817', 'sector': 'Industrials', 'ful...
# 29     MO  {'zip': '23230', 'sector': 'Consumer Defensive...
# 30    MON  {'zip': '46204', 'sector': 'Financial Services...
# 31    MRK  {'zip': '07033', 'sector': 'Healthcare', 'full...
# 32     MS  {'zip': '10036', 'sector': 'Financial Services...
# 33   MSFT  {'zip': '98052-6399', 'sector': 'Technology', ...
# 34    NEE  {'zip': '33408', 'sector': 'Utilities', 'fullT...
# 35    NKE  {'zip': '97005', 'sector': 'Consumer Cyclical'...
# 36   ORCL  {'zip': '78741', 'sector': 'Technology', 'full...
# 37    OXY  {'zip': '77046-0521', 'sector': 'Energy', 'ful...
# 38    PEP  {'zip': '10577', 'sector': 'Consumer Defensive...
# 39    PFE  {'zip': '10017', 'sector': 'Healthcare', 'full...
# 40     PG  {'zip': '45202', 'sector': 'Consumer Defensive...
# 41     PM  {'zip': '10017-5592', 'sector': 'Consumer Defe...
# 42   PYPL  {'zip': '95131', 'sector': 'Financial Services...
# 43   QCOM  {'zip': '92121-1714', 'sector': 'Technology', ...
# 44   SBUX  {'zip': '98134', 'sector': 'Consumer Cyclical'...
# 45    SLB  {'zip': '77056', 'sector': 'Energy', 'fullTime...
# 46     SO  {'zip': '30308', 'sector': 'Utilities', 'fullT...
# 47    SPG  {'zip': '46204', 'sector': 'Real Estate', 'ful...
# 48      T  {'zip': '75202', 'sector': 'Communication Serv...
# 49    TGT  {'zip': '55403', 'sector': 'Consumer Defensive...
# 50    TXN  {'zip': '75243', 'sector': 'Technology', 'full...
# 51    UNH  {'zip': '55343', 'sector': 'Healthcare', 'full...
# 52    UNP  {'zip': '68179', 'sector': 'Industrials', 'ful...
# 53    UPS  {'zip': '30328', 'sector': 'Industrials', 'ful...

# %%
tickers_df.to_csv('filtered-data.csv', index=False)

# %% [markdown]
# ## Contribution Declaration
#
# The following team members made a meaningful contribution to this assignment:
#
# Insert Names Here.
