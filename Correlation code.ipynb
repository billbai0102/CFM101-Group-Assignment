# %%
from IPython.display import display, Math, Latex

import pandas as pd
import numpy as np
import numpy_financial as npf
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ## Group Assignment
# ### Team Number: 12
# ### Team Member Names: Bill Bai, Soumik Debnath, Justin Yu
# ### Team Strategy Chosen: __________(RISKY OR SAFE)

# %%
ticker_df=pd.read_csv("filtered-data.csv")
ticker_df
# Out:
#      AAPL                                               Info
# 0    ABBV  {'zip': '60064-6400', 'sector': 'Healthcare', ...
# 1     ABT  {'zip': '60064-6400', 'sector': 'Healthcare', ...
# 2     ACN  {'zip': '2', 'sector': 'Technology', 'fullTime...
# 3     AIG  {'zip': '10020', 'sector': 'Financial Services...
# 4    AMZN  {'zip': '98109-5210', 'sector': 'Consumer Cycl...
# 5     AXP  {'zip': '10285', 'sector': 'Financial Services...
# 6      BA  {'zip': '60606-1596', 'sector': 'Industrials',...
# 7     BAC  {'zip': '28255', 'sector': 'Financial Services...
# 8    BIIB  {'zip': '02142', 'sector': 'Healthcare', 'full...
# 9      BK  {'zip': '10286', 'sector': 'Financial Services...
# 10    BLK  {'zip': '10055', 'sector': 'Financial Services...
# 11    BMY  {'zip': '10016', 'sector': 'Healthcare', 'full...
# 12      C  {'zip': '10013', 'sector': 'Financial Services...
# 13    CAT  {'zip': '60015', 'sector': 'Industrials', 'ful...
# 14     CL  {'zip': '10022-7499', 'sector': 'Consumer Defe...
# 15  CMCSA  {'zip': '19103-2838', 'sector': 'Communication...
# 16    COF  {'zip': '22102', 'sector': 'Financial Services...
# 17    COP  {'zip': '77079-2703', 'sector': 'Energy', 'ful...
# 18   COST  {'zip': '98027', 'sector': 'Consumer Defensive...
# 19   CSCO  {'zip': '95134', 'sector': 'Technology', 'full...
# 20    CVS  {'zip': '02895', 'sector': 'Healthcare', 'full...
# 21     GM  {'zip': '48265-3000', 'sector': 'Consumer Cycl...
# 22   GOOG  {'zip': '94043', 'sector': 'Communication Serv...
# 23    JPM  {'zip': '10179', 'sector': 'Financial Services...
# 24    KMI  {'zip': '77002', 'sector': 'Energy', 'fullTime...
# 25     KO  {'zip': '30313', 'sector': 'Consumer Defensive...
# 26    LLY  {'zip': '46285', 'sector': 'Healthcare', 'full...
# 27    LMT  {'zip': '20817', 'sector': 'Industrials', 'ful...
# 28     MO  {'zip': '23230', 'sector': 'Consumer Defensive...
# 29    MON  {'zip': '46204', 'sector': 'Financial Services...
# 30    MRK  {'zip': '07033', 'sector': 'Healthcare', 'full...
# 31     MS  {'zip': '10036', 'sector': 'Financial Services...
# 32   MSFT  {'zip': '98052-6399', 'sector': 'Technology', ...
# 33    NEE  {'zip': '33408', 'sector': 'Utilities', 'fullT...
# 34    NKE  {'zip': '97005-6453', 'sector': 'Consumer Cycl...
# 35   ORCL  {'zip': '78741', 'sector': 'Technology', 'full...
# 36    OXY  {'zip': '77046-0521', 'sector': 'Energy', 'ful...
# 37    PEP  {'zip': '10577', 'sector': 'Consumer Defensive...
# 38    PFE  {'zip': '10017', 'sector': 'Healthcare', 'full...
# 39     PG  {'zip': '45202', 'sector': 'Consumer Defensive...
# 40     PM  {'zip': '10017-5592', 'sector': 'Consumer Defe...
# 41   PYPL  {'zip': '95131', 'sector': 'Financial Services...
# 42   QCOM  {'zip': '92121-1714', 'sector': 'Technology', ...
# 43   SBUX  {'zip': '98134', 'sector': 'Consumer Cyclical'...
# 44    SLB  {'zip': '77056', 'sector': 'Energy', 'fullTime...
# 45     SO  {'zip': '30308', 'sector': 'Utilities', 'fullT...
# 46    SPG  {'zip': '46204', 'sector': 'Real Estate', 'ful...
# 47      T  {'zip': '75202', 'sector': 'Communication Serv...
# 48    TGT  {'zip': '55403', 'sector': 'Consumer Defensive...
# 49    TXN  {'zip': '75243', 'sector': 'Technology', 'full...
# 50    UNH  {'zip': '55343', 'sector': 'Healthcare', 'full...
# 51    UNP  {'zip': '68179', 'sector': 'Industrials', 'ful...
# 52    UPS  {'zip': '30328', 'sector': 'Industrials', 'ful...
# 53    USB  {'zip': '55402', 'sector': 'Financial Services...

# %%
#goes through the filtered list and creates a dataframe of their closing prices
def dataframer(df,start_date,end_date):
    dic={}
    for i in range(len(df.index)):
        tick=df.iloc[i,0]
        t=yf.Ticker(tick)
        t_hist=t.history(start=start_date, end=end_date)
        dic[tick]=t_hist.Close
    return dic
    
#creates the dataframe price using the function dataframer
prices=pd.DataFrame(dataframer(ticker_df, "2015-01-01", "2021-08-01"))
prices
# Out:
#                   ABBV         ABT         ACN        AIG         AMZN  \
# Date
# 2015-01-02   48.810196   39.254288   78.799759  47.397800   308.519989
# 2015-01-05   47.891628   39.263027   77.469269  46.460167   302.190002
# 2015-01-06   47.654583   38.817158   76.910469  45.801258   295.290009
# 2015-01-07   49.580605   39.131901   78.524803  46.020901   298.420013
# 2015-01-08   50.099171   39.936211   79.722221  45.818157   300.459991
# ...                ...         ...         ...        ...          ...
# 2021-07-26  116.379082  119.060303  318.035797  47.429508  3699.820068
# 2021-07-27  116.547043  119.349190  318.943115  47.141212  3626.389893
# 2021-07-28  117.129982  120.056458  315.373688  46.673977  3630.320068
# 2021-07-29  117.446144  120.624268  317.407654  47.588566  3599.919922
# 2021-07-30  114.906929  120.514694  316.739624  47.071625  3327.590088
#
#                    AXP          BA        BAC        BIIB         BK  ...  \
# Date                                                                  ...
# 2015-01-02   83.556084  113.657211  15.799913  342.010010  34.639473  ...
# 2015-01-05   81.346344  112.870071  15.340920  336.739990  33.749081  ...
# 2015-01-06   79.612717  111.540627  14.881931  334.649994  32.773090  ...
# 2015-01-07   81.351456  113.272354  14.952543  353.239990  33.449429  ...
# 2015-01-08   82.504623  115.275269  15.261480  350.250000  33.911755  ...
# ...                ...         ...        ...         ...        ...  ...
# 2021-07-26  172.181961  225.850006  37.935600  331.929993  49.962566  ...
# 2021-07-27  172.511154  222.270004  37.786366  333.959991  49.902908  ...
# 2021-07-28  169.598389  231.570007  37.935600  334.179993  50.061993  ...
# 2021-07-29  171.523590  231.630005  38.482796  329.170013  51.006557  ...
# 2021-07-30  170.107117  226.479996  38.164429  326.730011  51.036388  ...
#
#                   SLB         SO         SPG          T         TGT  \
# Date
# 2015-01-02  69.114510  35.873730  136.030167  22.462128   61.676899
# 2015-01-05  67.242836  35.721138  136.587921  22.249905   60.571583
# 2015-01-06  65.927826  36.149860  140.389847  22.283064   60.563389
# 2015-01-07  65.919762  36.549496  142.973297  22.309973   62.855888
# 2015-01-08  66.718452  36.578568  142.767807  22.531929   63.150639
# ...               ...        ...         ...        ...         ...
# 2021-07-26  29.329782  62.429565  125.614151  27.643435  259.082672
# 2021-07-27  29.051022  63.223038  124.467087  27.663055  256.599701
# 2021-07-28  29.190403  62.684261  123.824326  27.476671  255.666138
# 2021-07-29  29.508987  63.144669  124.516525  27.751341  259.877258
# 2021-07-30  28.702568  62.566708  125.109833  27.515909  259.271393
#
#                    TXN         UNH         UNP         UPS        USB
# Date
# 2015-01-02   44.549072   90.677483  102.170197   89.539307  36.932411
# 2015-01-05   43.857689   89.183884   98.715996   87.746597  36.042675
# 2015-01-06   43.132957   89.003944   96.674500   87.170639  35.564846
# 2015-01-07   43.907669   89.912689   97.208549   87.981819  35.877907
# 2015-01-08   44.624050   94.204521  100.852264   89.563667  36.141537
# ...                ...         ...         ...         ...        ...
# 2021-07-26  187.107605  412.093536  219.125992  207.730637  55.752281
# 2021-07-27  183.996765  413.648071  216.976425  193.209473  55.722511
# 2021-07-28  185.706238  407.738831  215.513535  190.091431  55.613350
# 2021-07-29  188.667999  410.638611  216.269867  189.863770  56.010300
# 2021-07-30  189.453156  410.778137  217.702896  189.418335  55.117153
#
# [1656 rows x 54 columns]

# %%
#creates a dictionary of tickers and their std over a certain time period
def stdlister(df):
    column=df.columns
    stdlst_dic={}

    for i in range(len(column)):
        temp=df[str(column[i])].pct_change().std()
        stdlst_dic[str(column[i])]=temp
    return stdlst_dic

#creates the dataframe slst which is a dictionary containing the tickers and their std
slst=stdlister(prices)
slst
# Out:
# {'ABBV': 0.018181891912063288,
#  'ABT': 0.015544129593684931,
#  'ACN': 0.015134940935556103,
#  'AIG': 0.02185596403436045,
#  'AMZN': 0.01924427749248993,
#  'AXP': 0.020047004122865197,
#  'BA': 0.026512098588026556,
#  'BAC': 0.020772962783402772,
#  'BIIB': 0.028748165799199733,
#  'BK': 0.01780009782873713,
#  'BLK': 0.0174823272534209,
#  'BMY': 0.016195319135314967,
#  'C': 0.0220913106023932,
#  'CAT': 0.018993871690924095,
#  'CL': 0.012598083009196896,
#  'CMCSA': 0.015571451804709528,
#  'COF': 0.023099386258302292,
#  'COP': 0.0259215596853469,
#  'COST': 0.012905206866992725,
#  'CSCO': 0.016465542557492406,
#  'CVS': 0.016748464393566403,
#  'GM': 0.021886276233157993,
#  'GOOG': 0.016886465120562095,
#  'JPM': 0.018135684348093577,
#  'KMI': 0.021948964234542314,
#  'KO': 0.011884006825417646,
#  'LLY': 0.017247588995952606,
#  'LMT': 0.014363414236807249,
#  'MO': 0.014814577020986316,
#  'MON': 0.005298253476202799,
#  'MRK': 0.013681839427459657,
#  'MS': 0.020842331076824608,
#  'MSFT': 0.01720361524520878,
#  'NEE': 0.014283490109409436,
#  'NKE': 0.017453383193632703,
#  'ORCL': 0.01597373066595147,
#  'OXY': 0.03247511303450251,
#  'PEP': 0.01232508028668171,
#  'PFE': 0.013567011708660962,
#  'PG': 0.01206784479644911,
#  'PM': 0.015304613456062929,
#  'PYPL': 0.021785893122774493,
#  'QCOM': 0.022564240625093542,
#  'SBUX': 0.016469022000705696,
#  'SLB': 0.02524527917524015,
#  'SO': 0.014558302729868583,
#  'SPG': 0.0257191612018187,
#  'T': 0.013647616168826246,
#  'TGT': 0.0182350438692907,
#  'TXN': 0.018191082183430768,
#  'UNH': 0.017163737649805052,
#  'UNP': 0.017028353368836572,
#  'UPS': 0.015767686731387294,
#  'USB': 0.01827177827873324}

# %%
#function to find the highest std
def high_std(dic):
    std=0
    tick=""
    for i in dic:
        if std < dic[i]:
            std=dic[i]
            tick=i
    return tick

#checking what the highest std is
high_std(slst)
# Out:
# 'OXY'

# %%
#creating a correlation dataframe
corr_df=prices.corr()
corr_df
# Out:
#            ABBV       ABT       ACN       AIG      AMZN       AXP        BA  \
# ABBV   1.000000  0.855582  0.895960 -0.352321  0.889050  0.833081  0.498533
# ABT    0.855582  1.000000  0.968198 -0.534148  0.966034  0.877578  0.394552
# ACN    0.895960  0.968198  1.000000 -0.407402  0.970793  0.904533  0.419075
# AIG   -0.352321 -0.534148 -0.407402  1.000000 -0.551709 -0.182825  0.037009
# AMZN   0.889050  0.966034  0.970793 -0.551709  1.000000  0.825634  0.373884
# AXP    0.833081  0.877578  0.904533 -0.182825  0.825634  1.000000  0.621778
# BA     0.498533  0.394552  0.419075  0.037009  0.373884  0.621778  1.000000
# BAC    0.879334  0.799053  0.858846 -0.087897  0.791242  0.934424  0.706793
# BIIB  -0.076470 -0.216789 -0.269957  0.070506 -0.261863 -0.121423 -0.153177
# BK     0.555506  0.256421  0.367651  0.365292  0.286649  0.559914  0.757513
# BLK    0.927913  0.892406  0.945614 -0.287571  0.911564  0.864683  0.325811
# BMY    0.463230  0.387560  0.424760 -0.190431  0.387007  0.267883 -0.248517
# C      0.667229  0.500801  0.579006  0.280417  0.464595  0.782794  0.781576
# CAT    0.942804  0.880636  0.925370 -0.232740  0.884735  0.907292  0.526097
# CL     0.731304  0.812465  0.858005 -0.291990  0.828162  0.697012  0.127126
# CMCSA  0.817257  0.902408  0.945368 -0.228795  0.882852  0.896591  0.411042
# COF    0.719259  0.619262  0.717956  0.203528  0.591161  0.849796  0.444026
# COP    0.318576  0.193411  0.203140  0.186731  0.143267  0.514273  0.748463
# COST   0.830095  0.977364  0.970332 -0.535363  0.965352  0.855701  0.354181
# CSCO   0.797793  0.847380  0.857816 -0.343179  0.834454  0.897543  0.747238
# CVS   -0.375640 -0.394905 -0.374894  0.330367 -0.444437 -0.357027 -0.644996
# KMI   -0.335740 -0.146523 -0.364731 -0.409313 -0.241299 -0.252610 -0.128892
# KO     0.469467  0.774993  0.898533  0.891865  0.901039  0.734237  0.631042
# LLY    0.167714  0.928236  0.914078  0.909582  0.901393  0.839224  0.415727
# LMT    0.503269  0.672348  0.889497  0.902348  0.883035  0.662199  0.587082
# MO     0.410233 -0.242428 -0.079234 -0.075798 -0.203235  0.014735  0.404858
# MON    0.306660 -0.411437  0.063532 -0.286601  0.173755 -0.351439 -0.002695
# MRK    0.383758  0.691674  0.832949  0.849779  0.896662  0.621829  0.495734
# MS     0.232968  0.843504  0.902704  0.871944  0.842169  0.888585  0.708610
# MSFT   0.250303  0.921917  0.965460  0.954976  0.949777  0.861754  0.450155
# NEE    0.314343  0.877787  0.958607  0.946187  0.951823  0.820408  0.458310
# NKE    0.187871  0.944276  0.943584  0.919641  0.930050  0.882181  0.454742
# ORCL   0.258531  0.889742  0.945836  0.925098  0.923801  0.890425  0.639003
# OXY   -0.179758 -0.741050 -0.662243 -0.641669 -0.651501 -0.615613 -0.007448
# PEP    0.440594  0.823697  0.936457  0.925057  0.926340  0.785047  0.542948
# PFE    0.189266  0.651852  0.826404  0.883191  0.881551  0.658302  0.619031
# PG     0.363861  0.859651  0.903239  0.877027  0.911079  0.800087  0.418292
# PM     0.566068  0.306292  0.436126  0.413067  0.293265  0.498333  0.581799
# PYPL   0.049494  0.950046  0.957518  0.929160  0.922406  0.909884  0.413003
# QCOM   0.169717  0.946635  0.889085  0.833585  0.867293  0.900336  0.376766
# SBUX   0.329763  0.905413  0.911263  0.863134  0.892939  0.835643  0.539137
# SLB   -0.169087 -0.709121 -0.795936 -0.818781 -0.829619 -0.595127 -0.218410
# SO     0.514234  0.820642  0.883573  0.851599  0.868131  0.745663  0.519885
# SPG    0.005904 -0.522821 -0.523404 -0.537271 -0.509549 -0.437330  0.159551
# T      1.000000  0.154652  0.319573  0.279398  0.242046  0.204056  0.512569
# TGT    0.154652  1.000000  0.882106  0.838969  0.847218  0.918980  0.397034
# TXN    0.319573  0.882106  1.000000  0.972548  0.964616  0.883305  0.616937
# UNH    0.279398  0.838969  0.972548  1.000000  0.959183  0.840088  0.597214
# UNP    0.242046  0.847218  0.964616  0.959183  1.000000  0.818577  0.588470
# UPS    0.204056  0.918980  0.883305  0.840088  0.818577  1.000000  0.516417
# USB    0.512569  0.397034  0.616937  0.597214  0.588470  0.516417  1.000000
#
# [54 rows x 54 columns]

# %%
#function to find the correlation of tickers against one ticker to return a dictionary
# which contains two lists of tickers, one positive correlating with the original ticker and other one negatively
def lister(corr,high_std):
    list1=[]
    list2=[]
    columns=corr.columns
    for i in range(len(corr.index)):
        c=corr[high_std].iloc[i]
        tick=columns[i]
        if c > 0:
            list1.append(tick)
        elif c < 0:
            list2.append(tick)
    dic={"positive":list1,"negative":list2}
    return dic

#creates dictionary cor_list which calls the function lister
# contains two lists which are positive correlating and negative correlating with the inputed stock
cor_list=lister(corr_df, high_std(slst))
cor_list
# Out:
# {'positive': ['AIG',
#   'BA',
#   'BIIB',
#   'BK',
#   'COP',
#   'CVS',
#   'KMI',
#   'MO',
#   'OXY',
#   'SLB',
#   'SPG'],
#  'negative': ['ABBV',
#   'ABT',
#   'ACN',
#   'AMZN',
#   'AXP',
#   'BAC',
#   'BLK',
#   'BMY',
#   'C',
#   'CAT',
#   'CL',
#   'CMCSA',
#   'COF',
#   'COST',
#   'CSCO',
#   'GM',
#   'GOOG',
#   'JPM',
#   'KO',
#   'LLY',
#   'LMT',
#   'MON',
#   'MRK',
#   'MS',
#   'MSFT',
#   'NEE',
#   'NKE',
#   'ORCL',
#   'PEP',
#   'PFE',
#   'PG',
#   'PM',
#   'PYPL',
#   'QCOM',
#   'SBUX',
#   'SO',
#   'T',
#   'TGT',
#   'TXN',
#   'UNH',
#   'UNP',
#   'UPS',
#   'USB']}

# %%
def sorter(tick_lst,std_list):
    sequence=tick_lst
    length = len(sequence)
    if length <= 1:
        return sequence
    else:
        pivot=sequence.pop()

    items_greater=[]
    items_lower=[]
    
    for item in sequence:
        i=std_list[item]
        pivoter=std_list[pivot]
        if i < pivoter:
            items_lower.append(item)
        else:
            items_greater.append(item)
    
    return sorter(items_greater,slst)+[pivot]+sorter(items_lower,slst)

positive=sorter(cor_list["positive"], slst)
negative=(sorter(cor_list["negative"], slst))

positive
# Out:
# ['OXY', 'BIIB', 'BA', 'COP', 'SPG', 'SLB', 'KMI', 'AIG', 'BK', 'CVS', 'MO']

# %%
def meanstd(lst,count,std_list,sum,lst_tick):
    if 0 == len(lst):
        return {"list":lst_tick,"mean":(sum/count)}
    elif 10 == count:
        return {"list":lst_tick,"mean":(sum/10)}
    else:
        sum=sum+std_list[lst[0]]
        lst_tick.append(lst[0])
        return meanstd(lst[1:],(count+1),std_list,sum,lst_tick)

pm=meanstd(positive,0,slst,0,[])
nm=meanstd(negative,0,slst,0,[])


def hstd(p,n):
    if p["mean"] < n["mean"] and len(p["list"])>=7:
        p["oppo"]=negative
        return p
    elif n["mean"] < p["mean"] and len(n["list"])>=7:
        n["oppo"]=positive
        return n


port_list=hstd(pm,nm)
port_list
# Out:
# {'list': ['COF', 'QCOM', 'C', 'GM', 'PYPL', 'MS', 'BAC', 'AXP', 'AMZN', 'CAT'],
#  'mean': 0.021132755400822812,
#  'oppo': ['OXY',
#   'BIIB',
#   'BA',
#   'COP',
#   'SPG',
#   'SLB',
#   'KMI',
#   'AIG',
#   'BK',
#   'CVS',
#   'MO']}

# %%
port_list["oppo"][-2]
# Out:
# 'KO'

# %%
def portlength(port):
    if len(port["list"]) == 10:
        return port["list"]
    else:
        for i in range(1,10-len(port)):
            if i == 10:
                return port["list"]
            port["list"].append(port["oppo"][-1*i])

finalport=portlength(port_list)   
finalport
# Out:
# ['OXY', 'BIIB', 'BA', 'COP', 'SPG', 'SLB', 'KMI', 'AIG', 'BK', 'CVS']

# %% [markdown]
# ## Contribution Declaration
#
# The following team members made a meaningful contribution to this assignment:
#
# Insert Names Here.
