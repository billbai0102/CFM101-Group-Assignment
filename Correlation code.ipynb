# %%
from IPython.display import display, Math, Latex

import pandas as pd
import numpy as np
import numpy_financial as npf
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ## Group Assignment
# ### Team Number: 12
# ### Team Member Names: Bill Bai, Soumik Debnath, Justin Yu
# ### Team Strategy Chosen: __________(RISKY OR SAFE)

# %%
ticker_df=pd.read_csv("filtered-data.csv")
ticker_df
# Out:
#      AAPL                                               Info
# 0    ABBV  {'zip': '60064-6400', 'sector': 'Healthcare', ...
# 1     ABT  {'zip': '60064-6400', 'sector': 'Healthcare', ...
# 2     ACN  {'zip': '2', 'sector': 'Technology', 'fullTime...
# 3     AIG  {'zip': '10020', 'sector': 'Financial Services...
# 4    AMZN  {'zip': '98109-5210', 'sector': 'Consumer Cycl...
# 5     AXP  {'zip': '10285', 'sector': 'Financial Services...
# 6      BA  {'zip': '60606-1596', 'sector': 'Industrials',...
# 7     BAC  {'zip': '28255', 'sector': 'Financial Services...
# 8    BIIB  {'zip': '02142', 'sector': 'Healthcare', 'full...
# 9      BK  {'zip': '10286', 'sector': 'Financial Services...
# 10    BLK  {'zip': '10055', 'sector': 'Financial Services...
# 11    BMY  {'zip': '10016', 'sector': 'Healthcare', 'full...
# 12      C  {'zip': '10013', 'sector': 'Financial Services...
# 13    CAT  {'zip': '60015', 'sector': 'Industrials', 'ful...
# 14     CL  {'zip': '10022-7499', 'sector': 'Consumer Defe...
# 15  CMCSA  {'zip': '19103-2838', 'sector': 'Communication...
# 16    COF  {'zip': '22102', 'sector': 'Financial Services...
# 17    COP  {'zip': '77079-2703', 'sector': 'Energy', 'ful...
# 18   COST  {'zip': '98027', 'sector': 'Consumer Defensive...
# 19   CSCO  {'zip': '95134', 'sector': 'Technology', 'full...
# 20    CVS  {'zip': '02895', 'sector': 'Healthcare', 'full...
# 21     GM  {'zip': '48265-3000', 'sector': 'Consumer Cycl...
# 22   GOOG  {'zip': '94043', 'sector': 'Communication Serv...
# 23    JPM  {'zip': '10179', 'sector': 'Financial Services...
# 24    KMI  {'zip': '77002', 'sector': 'Energy', 'fullTime...
# 25     KO  {'zip': '30313', 'sector': 'Consumer Defensive...
# 26    LLY  {'zip': '46285', 'sector': 'Healthcare', 'full...
# 27    LMT  {'zip': '20817', 'sector': 'Industrials', 'ful...
# 28     MO  {'zip': '23230', 'sector': 'Consumer Defensive...
# 29    MON  {'zip': '46204', 'sector': 'Financial Services...
# 30    MRK  {'zip': '07033', 'sector': 'Healthcare', 'full...
# 31     MS  {'zip': '10036', 'sector': 'Financial Services...
# 32   MSFT  {'zip': '98052-6399', 'sector': 'Technology', ...
# 33    NEE  {'zip': '33408', 'sector': 'Utilities', 'fullT...
# 34    NKE  {'zip': '97005-6453', 'sector': 'Consumer Cycl...
# 35   ORCL  {'zip': '78741', 'sector': 'Technology', 'full...
# 36    OXY  {'zip': '77046-0521', 'sector': 'Energy', 'ful...
# 37    PEP  {'zip': '10577', 'sector': 'Consumer Defensive...
# 38    PFE  {'zip': '10017', 'sector': 'Healthcare', 'full...
# 39     PG  {'zip': '45202', 'sector': 'Consumer Defensive...
# 40     PM  {'zip': '10017-5592', 'sector': 'Consumer Defe...
# 41   PYPL  {'zip': '95131', 'sector': 'Financial Services...
# 42   QCOM  {'zip': '92121-1714', 'sector': 'Technology', ...
# 43   SBUX  {'zip': '98134', 'sector': 'Consumer Cyclical'...
# 44    SLB  {'zip': '77056', 'sector': 'Energy', 'fullTime...
# 45     SO  {'zip': '30308', 'sector': 'Utilities', 'fullT...
# 46    SPG  {'zip': '46204', 'sector': 'Real Estate', 'ful...
# 47      T  {'zip': '75202', 'sector': 'Communication Serv...
# 48    TGT  {'zip': '55403', 'sector': 'Consumer Defensive...
# 49    TXN  {'zip': '75243', 'sector': 'Technology', 'full...
# 50    UNH  {'zip': '55343', 'sector': 'Healthcare', 'full...
# 51    UNP  {'zip': '68179', 'sector': 'Industrials', 'ful...
# 52    UPS  {'zip': '30328', 'sector': 'Industrials', 'ful...
# 53    USB  {'zip': '55402', 'sector': 'Financial Services...

# %%
def dataframer(df,start_date,end_date):
    dic={}
    for i in range(len(df.index)):
        tick=df.iloc[i,0]
        t=yf.Ticker(tick)
        t_hist=t.history(start=start_date, end=end_date)
        dic[tick]=t_hist.Close
    return dic
    

prices=pd.DataFrame(dataframer(ticker_df, "2021-01-01", "2021-08-01"))
prices
# Out:
#                   ABBV         ABT         ACN        AIG         AMZN  \
# Date
# 2021-01-04  100.585396  107.449142  253.328720  36.442303  3186.629883
# 2021-01-05  101.625504  108.778587  254.770905  37.050823  3218.510010
# 2021-01-06  100.747612  108.552101  257.556458  39.465256  3138.379883
# 2021-01-07  101.825897  109.605804  259.986450  40.132660  3162.159912
# 2021-01-08  102.360252  109.911087  260.934723  39.867664  3182.699951
# ...                ...         ...         ...        ...          ...
# 2021-07-26  116.379082  119.060303  318.035797  47.429508  3699.820068
# 2021-07-27  116.547043  119.349190  318.943115  47.141212  3626.389893
# 2021-07-28  117.129982  120.056458  315.373688  46.673977  3630.320068
# 2021-07-29  117.446144  120.624268  317.407654  47.588566  3599.919922
# 2021-07-30  114.906929  120.514694  316.739624  47.071625  3327.590088
#
#                    AXP          BA        BAC        BIIB         BK  ...  \
# Date                                                                  ...
# 2021-01-04  116.679779  202.720001  29.604614  242.949997  40.592575  ...
# 2021-01-05  117.302521  211.630005  29.831354  246.389999  41.050205  ...
# 2021-01-06  121.641930  211.029999  31.694584  247.750000  43.825184  ...
# 2021-01-07  120.679756  212.710007  32.394527  250.440002  44.088074  ...
# 2021-01-08  120.798782  209.899994  32.069199  252.539993  43.620708  ...
# ...                ...         ...        ...         ...        ...  ...
# 2021-07-26  172.181961  225.850006  37.935600  331.929993  49.962566  ...
# 2021-07-27  172.511154  222.270004  37.786366  333.959991  49.902908  ...
# 2021-07-28  169.598389  231.570007  37.935600  334.179993  50.061993  ...
# 2021-07-29  171.523590  231.630005  38.482796  329.170013  51.006557  ...
# 2021-07-30  170.107117  226.479996  38.164429  326.730011  51.036388  ...
#
#                   SLB         SO         SPG          T         TGT  \
# Date
# 2021-01-04  21.664156  56.963764   80.108383  27.398785  175.223892
# 2021-01-05  22.828789  57.338020   80.456635  27.231264  177.926788
# 2021-01-06  24.092119  58.739082   82.294655  27.761745  186.360947
# 2021-01-07  24.556000  58.671906   82.352692  27.836197  188.511459
# 2021-01-08  24.516521  59.084549   83.668327  27.485758  190.977585
# ...               ...        ...         ...        ...         ...
# 2021-07-26  29.329782  62.429565  125.614151  27.643435  259.082642
# 2021-07-27  29.051022  63.223038  124.467087  27.663055  256.599701
# 2021-07-28  29.190403  62.684261  123.824326  27.476671  255.666138
# 2021-07-29  29.508987  63.144669  124.516525  27.751341  259.877228
# 2021-07-30  28.702568  62.566708  125.109833  27.515909  259.271362
#
#                    TXN         UNH         UNP         UPS        USB
# Date
# 2021-01-04  158.491638  345.778137  200.139648  160.349716  45.091579
# 2021-01-05  159.654312  341.128174  202.594452  158.117737  45.238235
# 2021-01-06  160.445679  355.444122  206.833649  157.647827  47.917133
# 2021-01-07  164.080185  361.142761  209.712357  155.650818  48.875290
# 2021-01-08  167.226181  359.520264  215.726120  155.053650  48.220226
# ...                ...         ...         ...         ...        ...
# 2021-07-26  187.107605  412.093536  219.125992  207.730637  55.752281
# 2021-07-27  183.996765  413.648071  216.976425  193.209473  55.722511
# 2021-07-28  185.706238  407.738831  215.513535  190.091431  55.613350
# 2021-07-29  188.667999  410.638611  216.269867  189.863770  56.010300
# 2021-07-30  189.453156  410.778137  217.702896  189.418335  55.117153
#
# [145 rows x 54 columns]

# %%
def stdlister(df):
    column=df.columns
    stdlst_dic={}
    for i in range(len(df.columns)):
        temp=df[str(column[i])].pct_change().std()
        stdlst_dic[str(column[i])]=temp
    return stdlst_dic
        
slst=stdlister(prices)
slst
# Out:
# {'ABBV': 0.012465911792877675,
#  'ABT': 0.014808142433872257,
#  'ACN': 0.011359551980577129,
#  'AIG': 0.019934753121112068,
#  'AMZN': 0.016049381358997097,
#  'AXP': 0.016858929407161515,
#  'BA': 0.023265826332666068,
#  'BAC': 0.01683089217089312,
#  'BIIB': 0.03739069449584634,
#  'BK': 0.017270729135459184,
#  'BLK': 0.015230776355125058,
#  'BMY': 0.011520775653501562,
#  'C': 0.01778194579655739,
#  'CAT': 0.01633535982892165,
#  'CL': 0.009677718373655138,
#  'CMCSA': 0.014466889120493766,
#  'COF': 0.019610850367208388,
#  'COP': 0.024314386057458948,
#  'COST': 0.010814736669331847,
#  'CSCO': 0.011545046082031043,
#  'CVS': 0.01313512648435875,
#  'GM': 0.024803353293672968,
#  'GOOG': 0.016005219411813366,
#  'JPM': 0.014122038750024385,
#  'KMI': 0.01636333115089153,
#  'KO': 0.009288399805421024,
#  'LLY': 0.021130311393433295,
#  'LMT': 0.010895905777657713,
#  'MO': 0.013852292169820693,
#  'MON': 0.005298253476202799,
#  'MRK': 0.01136657665452619,
#  'MS': 0.017322407163678923,
#  'MSFT': 0.013326710265469076,
#  'NEE': 0.015281181074432054,
#  'NKE': 0.0194515759260349,
#  'ORCL': 0.016441761055415127,
#  'OXY': 0.03969470330762278,
#  'PEP': 0.009431734649939514,
#  'PFE': 0.010083069376313616,
#  'PG': 0.009676251030983846,
#  'PM': 0.01063577988529631,
#  'PYPL': 0.023930216250756645,
#  'QCOM': 0.021486749794415578,
#  'SBUX': 0.014058101764703602,
#  'SLB': 0.02781721296289151,
#  'SO': 0.01053752434219535,
#  'SPG': 0.021063606621066405,
#  'T': 0.011376197507056254,
#  'TGT': 0.015209057655821435,
#  'TXN': 0.019218723280782647,
#  'UNH': 0.011710624269513708,
#  'UNP': 0.013880069991449744,
#  'UPS': 0.016482836334150073,
#  'USB': 0.018001388685205365}

# %%
def high_std(dic):
    std=0
    tick=""
    for i in dic:
        if std < dic[i]:
            std=dic[i]
            tick=i
    return tick
        
high_std(slst)
# Out:
# 'OXY'

# %%
corr_df=prices.corr()
corr_df
# Out:
#            ABBV       ABT       ACN       AIG      AMZN       AXP        BA  \
# ABBV   1.000000 -0.209469  0.817221  0.630218  0.640144  0.817973  0.152971
# ABT   -0.209469  1.000000  0.062838 -0.173378  0.136832 -0.103125 -0.084390
# ACN    0.817221  0.062838  1.000000  0.607816  0.755833  0.879434  0.378636
# AIG    0.630218 -0.173378  0.607816  1.000000  0.140900  0.833755  0.728303
# AMZN   0.640144  0.136832  0.755833  0.140900  1.000000  0.577768 -0.025042
# AXP    0.817973 -0.103125  0.879434  0.833755  0.577768  1.000000  0.554889
# BA     0.152971 -0.084390  0.378636  0.728303 -0.025042  0.554889  1.000000
# BAC    0.627884 -0.134646  0.680516  0.963135  0.231128  0.849821  0.754664
# BIIB   0.600895 -0.315757  0.533511  0.392377  0.590417  0.655230  0.211939
# BK     0.787156 -0.247144  0.795451  0.895601  0.361667  0.881465  0.589692
# BLK    0.866803 -0.241480  0.876471  0.727808  0.668574  0.883146  0.395949
# BMY    0.864729 -0.245759  0.816851  0.487233  0.666905  0.719042  0.184168
# C      0.400735 -0.208616  0.402281  0.928183 -0.127589  0.629738  0.790703
# CAT    0.341876  0.039623  0.421728  0.877941 -0.097808  0.595304  0.770669
# CL     0.757554 -0.337730  0.672137  0.438128  0.548994  0.562376  0.027826
# CMCSA  0.660530  0.026142  0.776471  0.813384  0.418785  0.910200  0.618283
# COF    0.845203 -0.156682  0.834311  0.892337  0.508013  0.964712  0.522999
# COP    0.632697 -0.197044  0.630402  0.854581  0.277012  0.895907  0.667431
# COST   0.823019 -0.131152  0.848936  0.351280  0.817159  0.680712  0.004438
# CSCO   0.756394 -0.011738  0.899009  0.803520  0.576678  0.909719  0.597852
# CVS    0.847723 -0.342116  0.703154  0.756040  0.440067  0.781408  0.328801
# GM     0.395092  0.013502  0.494381  0.749087  0.272734  0.677436  0.763892
# GOOG   0.810853  0.050668  0.898044  0.714153  0.742187  0.944974  0.419891
# MO     0.552952  0.479959  0.776283  0.691066  0.746309  0.592818  0.868399
# MON    0.306660 -0.411437  0.063532 -0.286601  0.173755 -0.351439 -0.002695
# MRK   -0.097260  0.623473  0.278615  0.540363  0.335601  0.406849  0.156036
# MS     0.164506  0.847946  0.702039  0.829280  0.692935  0.837023  0.800157
# MSFT   0.068956  0.877214  0.784560  0.715775  0.511839  0.707931  0.554562
# NEE   -0.298324 -0.210456 -0.251645 -0.423178 -0.410266 -0.450162 -0.642928
# NKE   -0.361785  0.565044  0.209338  0.261173  0.042186  0.245871 -0.009646
# ORCL   0.289198  0.893080  0.788030  0.913259  0.750500  0.882393  0.819050
# OXY    0.040661  0.434967  0.480711  0.373696  0.412634  0.448489  0.539545
# PEP    0.161037  0.918621  0.685614  0.869226  0.634316  0.787352  0.587033
# PFE    0.297585  0.884032  0.648267  0.924909  0.687632  0.865496  0.691567
# PG     0.290846  0.748451  0.599399  0.802056  0.661805  0.664533  0.569740
# PM     0.354543  0.871804  0.812311  0.916262  0.781731  0.911388  0.866461
# PYPL  -0.263649  0.693519  0.569353  0.340086  0.232129  0.440591  0.217575
# QCOM  -0.490022 -0.091324 -0.323758 -0.362750 -0.447923 -0.369640 -0.690206
# SBUX   0.326844  0.806271  0.798838  0.832340  0.729566  0.731363  0.754774
# SLB    0.218306  0.594352  0.560307  0.636998  0.647013  0.751254  0.760411
# SO     0.665253  0.623934  0.712019  0.857899  0.829572  0.783007  0.843401
# SPG    0.304215  0.740985  0.791740  0.764663  0.701242  0.811637  0.847949
# T      1.000000  0.020099  0.308033  0.458522  0.594009  0.385247  0.625846
# TGT    0.020099  1.000000  0.761199  0.839181  0.624971  0.834831  0.617255
# TXN    0.308033  0.761199  1.000000  0.744471  0.780216  0.689638  0.759319
# UNH    0.458522  0.839181  0.744471  1.000000  0.839755  0.917622  0.859552
# UNP    0.594009  0.624971  0.780216  0.839755  1.000000  0.763020  0.897668
# UPS    0.385247  0.834831  0.689638  0.917622  0.763020  1.000000  0.822628
# USB    0.625846  0.617255  0.759319  0.859552  0.897668  0.822628  1.000000
#
# [54 rows x 54 columns]

# %%
def lister(corr,high_std):
    list1=[]
    list2=[]
    columns=corr.columns
    for i in range(len(corr.index)):
        c=corr[high_std].iloc[i]
        tick=columns[i]
        if c > 0:
            list1.append(tick)
        elif c < 0:
            list2.append(tick)
    dic={"positive":list1,"negative":list2}
    return dic

cor_list=lister(corr_df, high_std(slst))
cor_list
# Out:
# {'positive': ['ABBV',
#   'ACN',
#   'AIG',
#   'AMZN',
#   'AXP',
#   'BA',
#   'BAC',
#   'BIIB',
#   'BK',
#   'BLK',
#   'BMY',
#   'C',
#   'CAT',
#   'CMCSA',
#   'COF',
#   'COP',
#   'COST',
#   'CSCO',
#   'CVS',
#   'GM',
#   'GOOG',
#   'JPM',
#   'KMI',
#   'KO',
#   'LLY',
#   'LMT',
#   'MO',
#   'MS',
#   'MSFT',
#   'NKE',
#   'ORCL',
#   'OXY',
#   'PEP',
#   'PFE',
#   'PM',
#   'PYPL',
#   'SBUX',
#   'SLB',
#   'SO',
#   'SPG',
#   'T',
#   'TGT',
#   'TXN',
#   'UNH',
#   'UNP',
#   'UPS',
#   'USB'],
#  'negative': ['ABT', 'CL', 'MON', 'MRK', 'NEE', 'PG', 'QCOM']}

# %%
def sorter(tick_lst,std_list):
    sequence=tick_lst
    length = len(sequence)
    if length <= 1:
        return sequence
    else:
        pivot=sequence.pop()

    items_greater=[]
    items_lower=[]
    
    for item in sequence:
        i=std_list[item]
        pivoter=std_list[pivot]
        if i < pivoter:
            items_lower.append(item)
        else:
            items_greater.append(item)
    
    return sorter(items_greater,slst)+[pivot]+sorter(items_lower,slst)

positive=sorter(cor_list["positive"], slst)
negative=(sorter(cor_list["negative"], slst))

positive
# Out:
# ['OXY',
#  'BIIB',
#  'SLB',
#  'GM',
#  'COP',
#  'PYPL',
#  'BA',
#  'LLY',
#  'SPG',
#  'AIG',
#  'COF',
#  'NKE',
#  'TXN',
#  'USB',
#  'C',
#  'MS',
#  'BK',
#  'AXP',
#  'BAC',
#  'UPS',
#  'ORCL',
#  'KMI',
#  'CAT',
#  'AMZN',
#  'GOOG',
#  'BLK',
#  'TGT',
#  'CMCSA',
#  'JPM',
#  'SBUX',
#  'UNP',
#  'MO',
#  'MSFT',
#  'CVS',
#  'ABBV',
#  'UNH',
#  'CSCO',
#  'BMY',
#  'T',
#  'ACN',
#  'LMT',
#  'COST',
#  'PM',
#  'SO',
#  'PFE',
#  'PEP',
#  'KO']

# %%
def meanstd(lst,count,std_list,sum,lst_tick):
    if 0 == len(lst):
        return {"list":lst_tick,"mean":(sum/count)}
    elif 10 == count:
        return {"list":lst_tick,"mean":(sum/10)}
    else:
        sum=sum+std_list[lst[0]]
        lst_tick.append(lst[0])
        return meanstd(lst[1:],(count+1),std_list,sum,lst_tick)

pm=meanstd(positive,0,slst,0,[])
nm=meanstd(negative,0,slst,0,[])


def hstd(p,n):
    if p["mean"] > n["mean"]:
        p["oppo"]=negative
        return p
    elif n["mean"] > p["mean"]:
        n["oppo"]=positive
        return n


port_list=hstd(pm,nm)
port_list
# Out:
# {'list': ['OXY',
#   'BIIB',
#   'SLB',
#   'GM',
#   'COP',
#   'PYPL',
#   'BA',
#   'LLY',
#   'SPG',
#   'AIG'],
#  'mean': 0.026334506383652707,
#  'oppo': ['QCOM', 'NEE', 'ABT', 'MRK', 'CL', 'PG', 'MON']}

# %%
port_list["oppo"][-2]
# Out:
# 'PG'

# %%
def portlength(port):
    if len(port["list"]) == 10:
        return port["list"]
    else:
        for i in range(1,10-len(port)):
            if i == 10:
                return port["list"]
            port["list"].append(port["oppo"][-1*i])

portlength(port_list)
# Out:
# ['OXY', 'BIIB', 'SLB', 'GM', 'COP', 'PYPL', 'BA', 'LLY', 'SPG', 'AIG']

# %% [markdown]
# ## Contribution Declaration
#
# The following team members made a meaningful contribution to this assignment:
#
# Insert Names Here.
